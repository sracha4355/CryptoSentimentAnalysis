# %% [markdown]
# # Twitter-Crypto Popularity Predictor
# ## 10/30/21
# ## By: Jaden L, Nishith S, Satvik R, & Rohan B

# %% [markdown]
# ## i. Boiler Plate, authorization

# %%
import tweepy as twp
from textblob import TextBlob

from dotenv import load_dotenv
import os

load_dotenv()

#consumer keys
API_KEY = "4084w6OgZgpfCPokKiptoOu0d"
API_KEY_SECRET = "0hoOMwSSWtk1A3MpEz8DnvHldwBeQILWHPAKH3urzqeM1NXbRA"
#other
BEARER_TOKEN="AAAAAAAAAAAAAAAAAAAAACofVQEAAAAA37oDeWUoJjHHjFGcZIB7Hczsxbw%3Dq9faBKvvgAcnkTycCSEg0VnzkloiQJMmGNhBQFRiwYOrwgcaIw"
ACCESS_TOKEN = "1454477188669923332-emJUzrZpc7De5Oe8VjV4WFc2hcKN33"
ACCESS_TOKEN_SECRET = "O5kSDeMZMyxTfEcSTSe6ySOSog3tSio4NO3q0Ud3HQxi0"


auth = twp.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = twp.API(auth)

# %% [markdown]
# ## ii. Finding Magnitude

# %%
# My Functions

def getPolarity(tweet):
    #return TextBlob.sentiments.(tweet)
    return TextBlob(tweet).sentiment.polarity


def getSentiment(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'


def find_account_value(tweet):
    #check verification
    #check followers
    value = 1
    ver = tweet.user.verified
    if(ver == True):
        value *= 1.10
    elif(tweet.user.followers_count > 100000):
        value *= 1.05
    else:
        value += 0.05
    return value


#Fids value/impact of a single tweet
#param: tweet - item: full item of all data regarding current tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def find_tweet_value(list_of_tweets, tweet):

    # getting tweet_likes
    tweet_likes = tweet.favorite_count
    tweet_rts = tweet.retweet_count

    #calculating averages
    total_likes = 0
    total_rts = 0
    for tweet in list_of_tweets:
        total_likes += tweet.favorite_count
        total_rts += tweet.retweet_count

    avg_likes = total_likes / len(list_of_tweets)
    avg_rts = total_rts / len(list_of_tweets)

    #initializing value
    value = 5
    
    #checking likes alt
    if tweet_likes > avg_likes:
        value += tweet_likes / avg_likes
    elif tweet_likes < avg_likes:
        value -= tweet_likes / avg_likes

    #checking retweets
    if tweet_rts > avg_rts:
        value += tweet_rts / avg_rts
    elif tweet_rts < avg_rts:
        value -= tweet_rts / avg_rts

    
    return value


def getMagnitude(list_of_tweets, tweet):
    pol = getPolarity(tweet.text)
    sen = getSentiment(pol)

    mag = 0

    if(sen == "Negative"):
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet) * -1
    elif(sen == "Neutral"):
        mag = 0
    else:
        mag = find_account_value(tweet) + find_tweet_value(list_of_tweets, tweet)
    
    return mag


def getConnotation(list_of_tweets):
    con = 0
    for tweet in list_of_tweets:
        con += getMagnitude(list_of_tweets, tweet)
    return con


#loops through tweets and prints all information regarding tweet
#param: list_of_tweets - int: a full list of tweets with all information regarding likes, user, retweets, etc.
def print_all_tweets(list_of_tweets):

    for tweet in list_of_tweets:
        tweet_value = find_tweet_value(list_of_tweets, tweet) #finding tweet value
        acc_value = find_account_value(tweet) #finding account value
        magnitude = getMagnitude(list_of_tweets, tweet)
        print(f"Verified: {tweet.user.verified}")
        print(f"{tweet.user.screen_name} tweeted: ") #prints username
        print("-----")
        print(tweet.text) #prints actual tweet text
        print("-----")
        print(f"# of likes: {tweet.favorite_count}") #prints likes
        print(f'# of retweets: {tweet.retweet_count}') #prints retweets
        print(f"Tweet Value: {tweet_value}") #prints tweet value
        print(f"Account Value: {acc_value}") #prints account value
        print(f"Tweet Magnitude: {magnitude}")

        #getting sentiment
        pol = getPolarity(tweet.text)
        sen = getSentiment(pol)
        print(f"Sentiment: {sen}") #prints sentiment
        
        print("-------------------------------------------------------------------------------") #seperates each tweet


#main function
def main():
    # user input
    user_search = input("What coin are you looking for? ")
    search_term = user_search + " -filter:retweets"

    # making a list of all tweets with my query
    search_tweets = api.search_tweets(q = search_term, lang = "en", count = 100000, result_type = "mixed")
    

    # shows me how many tweets api.search_tweets() gets
    print(user_search.upper())
    print(f"Number of tweets found: {len(search_tweets)}")
    print("------------------------------------------------------------------------------------------------------------------------")

    # loops through each tweet in search_tweets and prints information about each tweet
    print_all_tweets(search_tweets)
    
    connotation = getConnotation(search_tweets)
    print(f"CURRENT CONNOTATION: {connotation}")


main()
# Out:
# ETHEREUM
# Number of tweets found: 82
# ------------------------------------------------------------------------------------------------------------------------
# Verified: True
# FEGtoken tweeted:
# -----
# Tonight is a continuation of the weekly twitter spaces series.
#
# Topic tonight is #FEGtoken itself - from tokenoimc… https://t.co/ruFOibVK9K
# -----
# # of likes: 1209
# # of retweets: 305
# Tweet Value: 56.07656741164594
# Account Value: 1.1
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: True
# Blockworks_ tweeted:
# -----
# BREAKING: Delubac &amp; Cie becomes the first bank in France to offer #Bitcoin &amp; Ethereum trading and custody services
# -----
# # of likes: 1695
# # of retweets: 325
# Tweet Value: 67.36282042564764
# Account Value: 1.1
# Tweet Magnitude: 68.46282042564764
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: True
# WatcherGuru tweeted:
# -----
# JUST IN: 🇫🇷 French bank Delubac &amp; Cie will offer #Bitcoin, #Ethereum, and #Tezos.
# -----
# # of likes: 1268
# # of retweets: 277
# Tweet Value: 54.70484698547526
# Account Value: 1.1
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# deez_eem tweeted:
# -----
# @cptan1888 @elonmusk @KleeKaiETH @VitalikButerin @Ethereum_06 @Shibtoken You have been nothing but trouble in the K… https://t.co/BolaW1oFuI
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# ETHGasPriceBot tweeted:
# -----
# Slow 21 | Normal 22 | Fast 25.7 | Instant 33 👈 current Ethereum gas prices in gwei. DM me a price and I will DM you… https://t.co/2FeFvSb3b3
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# nolliechain tweeted:
# -----
# @EthPrayag @owocki @peterhaymond @ethereum @l2beatcom better yet— they’re actually consistent and predictable.
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @A31337500 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# uddin633 tweeted:
# -----
# @elonmusk I would like to appreciate you if you donate me ethereum because you bought a Twitter! 44billion dollars🔥… https://t.co/JDNPc4LvtD
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Msu2626 tweeted:
# -----
# @ETH_Daily @BabyDogeCoin @ethereum @Shibtoken @apecoin @AxieInfinity @StepApp_ @RadioCacaNFT @onbuffchain Blockchai… https://t.co/LOVNEJwGqr
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# alegraziani tweeted:
# -----
# Look what I found! Daydreaming collectible https://t.co/TfiucOAC5K #rarible #ethereum #nonfungible #digitalasset… https://t.co/Yd2ZEdJ9C1
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# CaptainLanger tweeted:
# -----
# @ftlive @IOHK_Charles @ethereum @InputOutputHK https://t.co/34O10rbnl9 for real actual news/Headlines about #Cardano #Ada
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# cityofthenis tweeted:
# -----
# 👀 You might like this.
#
# ☑️ It's now available on OpenSea.
#
# ☑️ It's now available on Ethereum blockchain.
#
# 🐼 Offer o… https://t.co/nTkenSfk38
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 6.030485483103284
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Haskell_plus tweeted:
# -----
# @maximus_bertus @xAdaErgonautxx Honestly, peeps think the erc20 converter is cool and what not, but if Ethereum can… https://t.co/35bl0P79di
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# superwin0_0 tweeted:
# -----
# @ethereum_yyds @SenshiiNFT @laofeiyyds Awesome give away! Passive income! Yes plz 😋🖖💪🙌👍
# @gabriel0247 @alenamaxy… https://t.co/gravmpJwZA
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DeepInDigital1 tweeted:
# -----
# @CoinMarketCap like you did during the disappearance of volume in Korean markets when xrp was racing ahead of the b… https://t.co/Lloolv3bQh
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# nolliechain tweeted:
# -----
# @EthPrayag @owocki @peterhaymond @ethereum @l2beatcom also algorand txn fees are &lt; 1 cent which is significantly ch… https://t.co/k2uufD81xu
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# NftAslan tweeted:
# -----
# Ethereum ROI Table
#
# Table calculation is done in PKR currency according to ETH value to PKR on the date of 4/30/20… https://t.co/LKlNGNvvwB
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# DjKingDomrbc tweeted:
# -----
# @Ethereum_06 This is a fake account
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# chswiger tweeted:
# -----
# geth full node #Ethereum sync almost done - after a long time!  using 90% of 2TB ssd's -   at block: 14680577 (Fri… https://t.co/sC3IQcshAO
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @Kapitan4ik9 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ozrikh tweeted:
# -----
# Countdown to the moon 🚀🌙
# @meta_syndicate  is about to launch. Get into the rocket now before it's too late
# #NFT… https://t.co/SP8uFzdoEa
# -----
# # of likes: 2
# # of retweets: 0
# Tweet Value: 4.960970966206569
# Account Value: 1.05
# Tweet Magnitude: -3.910970966206569
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @Parvez3213 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BowTiedGrey tweeted:
# -----
# @bowtiedlamb I believe in Bitcoin, Ethereum, animal protein, ammunition, and child labor.
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# SudanClark2 tweeted:
# -----
# 🎉FREE #NFT GIVEAWAY🎉
#
# To win:
#
# 1️⃣ Must Follow @SudanClark2
# 2️⃣ Like &amp; Retweet
# 3️⃣ Drop your #ETH wallet address… https://t.co/0LSDNZTvc1
# -----
# # of likes: 2
# # of retweets: 0
# Tweet Value: 4.960970966206569
# Account Value: 1.05
# Tweet Magnitude: 6.0109709662065685
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# x3tko tweeted:
# -----
# somehow I found someone's private key in .env file #reddit #ethereum #ETH #crypto https://t.co/noPE5lWOoI
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @heyhaveagr8time @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 6.030485483103284
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# cityofthenis tweeted:
# -----
# 👀 You might like this.
#
# ☑️ It's now available on OpenSea.
#
# ☑️ It's now available on Ethereum blockchain.
#
# 🐼 Offer o… https://t.co/fijXQNKOT3
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 6.030485483103284
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# KryptoKing13 tweeted:
# -----
# @cory_eth 1. @sassal0x back in AUS pumping out the @thedailygwei
# 2. @VitalikButerin update on the master “urge” fl… https://t.co/goG0nKwXJK
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @Liisu_Annie @PunkLVNFT @CryptoPunks88 Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ETHGasPriceBot tweeted:
# -----
# Slow 21 | Normal 22 | Fast 27 | Instant 41.4 👈 current Ethereum gas prices in gwei. DM me a price and I will DM you… https://t.co/jr4SMYlNau
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# mazhar_23 tweeted:
# -----
# Tip
# Get initialized on open sea well in advance of your launch date
# Gas Fee For Ethereum $125 to be on a safer sid… https://t.co/XmXnLe2SBg
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @DayaPawar7 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# mazhar_23 tweeted:
# -----
# it will not allow you to create your collection.
#
# thing to note here is that this is when you select what blockchai… https://t.co/FkHKXTtICx
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# SorareBot tweeted:
# -----
# Robin Zentner bought for 0.485 ETH (1366.35$) by therealarno on the primary market
#
# Season: 2021-2022
# Level: 0
# Ser… https://t.co/GNzPgSyzAZ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# ethersFather920 tweeted:
# -----
# @cryptogems555 @CrokiCoin @elonmusk @VitalikButerin @ethereum @cz_binance @binance @anndylian @kucoincom @coinbase… https://t.co/VQmIruiKDP
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @SaraiAng12 @PunkLVNFT @PunksNFTLV Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# JohnBeckleyNFT tweeted:
# -----
# We are proud to announce that Beks will make its artwalk on the Ethereum blockchain! 🚀
#
# #nft #nfts #NFTCollection… https://t.co/4Dok4xVTwJ
# -----
# # of likes: 7
# # of retweets: 1
# Tweet Value: 4.7732884916130995
# Account Value: 1.05
# Tweet Magnitude: 5.823288491613099
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# thisavro tweeted:
# -----
# Moi first collectible collection is coming 🚀🚀🥺🥰I'm so pumped.
# Watch this space closely 😉
#
# #NFTdrop #beautiful… https://t.co/VJXp18jY05
# -----
# # of likes: 2
# # of retweets: 0
# Tweet Value: 4.960970966206569
# Account Value: 1.05
# Tweet Magnitude: -3.910970966206569
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# BourbCrypNFTs tweeted:
# -----
# Who else wants to be an NFT Millionaire?..💲💰💵
# Raise your ✋if you do.  (❤️this. ♻️Retweet this.
# Let's 👀those NFTs.… https://t.co/Q36TCWIYyS
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DwightWashingt6 tweeted:
# -----
# New Video:
# https://t.co/BGblrNFoqT
# &gt;
# #Hex #Hexican #Hexicans #RichardHeartWin #Pulsex #Pulsechain #LiquidLoans… https://t.co/1iE6tO3aSt
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 6.030485483103284
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# nolliechain tweeted:
# -----
# @EthPrayag @owocki @peterhaymond @ethereum @l2beatcom im not sure what you mean by saying L2s are not as “mathemati… https://t.co/8PfDFzF7eZ
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @RzlxYoujichen @PunkLVNFT @PUNKLVUS Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @RexLicudan @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @GamerInimical @PunkLVNFT @CryptoPunkRich Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# noahmajor1776 tweeted:
# -----
# If you aren’t listening👂to @BanklessHQ with @TrustlessState and @RyanSAdams wyd https://t.co/bGB60g6ulx
# •
# #crypto… https://t.co/6zuVHABjfE
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Berkahrammadhan tweeted:
# -----
# @Ethereum_06 DONEEEE
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Loofsnft tweeted:
# -----
# If gas fee is in eth then that must mean Otherside is on the ethereum blockchain. Is it possible to sell secondary… https://t.co/JQGOYQkDk4
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: -3.9304854831032845
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# E8tisBabE tweeted:
# -----
# Art &amp; ARtist✨
#
# #NFTartist #ethereum #tezos #WomenInNFTs #analogcollage #bayarea #SF #hendrix #batman
# 👇… https://t.co/K7IV4Disx2
# -----
# # of likes: 0
# # of retweets: 1
# Tweet Value: 4.90989010989011
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# CoinHunterSTX tweeted:
# -----
# Pongo found #ethereum in a Blue vault at this location! Join me playing #coinhuntworld, It's awesome!… https://t.co/NswHDNvdJ7
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# SonicNfts_ tweeted:
# -----
# Listed on Opensea.
# Sonic '06- Darkness.
# .
# Price: 3 eth($8,452)
# .
# Floor price: 0.1 eth
# .
# #nft #collectibles #opensea… https://t.co/au8MyWrqtD
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Kumaverse1 tweeted:
# -----
# We are launching today🐻
# ✅ Pre-sale at 0.0018 ($5)
# ✅ Drop 1 (10 Kuma's)
# ✅ Marketplace (OpenSea no⛽)
# ✅ Link on bio
# Gr… https://t.co/vEMyEiiiBK
# -----
# # of likes: 2
# # of retweets: 0
# Tweet Value: 4.960970966206569
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# nolliechain tweeted:
# -----
# @EthPrayag @owocki @peterhaymond @ethereum @l2beatcom algorand is actually very decentralized, arguably more than e… https://t.co/nVVnMotm8E
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# sublimeslimes__ tweeted:
# -----
# Why am I interested in ? because I believe Ethereum and DeFi are the start of something greater.   It's one of the… https://t.co/xfvoWCsa0o
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# DeepInDigital1 tweeted:
# -----
# @washingtonpost the only thing less surprising @ this point is the sec directors bill hinman Jay Clayton Gary gensl… https://t.co/zxBF8k5itN
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @JasonO28560514 @PunkLVNFT @punkRicher2022 Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# UmohBenjamin3 tweeted:
# -----
# @WhatSwapOrg @ethereum Awesome update
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @Tamires71792819 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# nosratabadi tweeted:
# -----
# SOS Stock Price: Sos Ltd jumps as equities rebound alongside Bitcoin and Ethereum – FXStreet https://t.co/GNBtN601xg
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# RanaRos74304648 tweeted:
# -----
# Miranda found #ethereum in a User vault at this location! Join me playing #coinhuntworld, It's awesome!… https://t.co/vlHN5q397f
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# ETHGasPriceBot tweeted:
# -----
# Slow 21 | Normal 22.5 | Fast 30 | Instant 41 👈 current Ethereum gas prices in gwei. DM me a price and I will DM you… https://t.co/LxtY9ZBioa
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# cptan1888 tweeted:
# -----
# @Kboss70008695 @elonmusk @KleeKaiETH @VitalikButerin @Ethereum_06 @Shibtoken @CircaCrypto No used, I have tried my… https://t.co/JqNUePUgKy
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Ethnik_Gallery tweeted:
# -----
# @ApeSkyel 👹DIRTY LITTLE DEVULS 👹
#
# ✨0.5 $ETH Ethereum 1/1 NFT✨
# ✨Drop on @opensea✨
# ✨https://t.co/NJYRcXqxQU ✨… https://t.co/jhQpWt7Pbi
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @meteomerr1 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# StakeShuffle_ tweeted:
# -----
# 2022-04-29 Current Ticket Price: 219.96 $DCR / 12,583.91 $USD  $$$
#          63.51% of circulating supply staked ~ 8… https://t.co/totDD9IpNY
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# TheArtsRNotDead tweeted:
# -----
# You may purchase my Doge Trip NFT on Rarible now https://t.co/vBaG0fz5h2 #rarible #ethereum #nonfungible… https://t.co/j0FLeejb4L
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# Freundschuh91 tweeted:
# -----
# @GizzyNFT 0x97200408e84b97171d5A234234982aC96fe1d5FC
#
# This is an ERC-20 (Ethereum) address. Do not send USDC over a… https://t.co/oeoAqeG0Ck
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @Wispsi @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# luyi78132843 tweeted:
# -----
# Why Bitcoin, Ethereum, and Coinbase All Dropped on Friday . The cryptocurrency market had another bad end to the we… https://t.co/cSIg0u3CGz
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: -3.9304854831032845
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# shiqi84084285 tweeted:
# -----
# Why Bitcoin, Ethereum, and Coinbase All Dropped on Friday . The cryptocurrency market had another bad end to the we… https://t.co/6QIulnOn0U
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# le_sh1n tweeted:
# -----
# @NftsBuy Well if Superman is the hero that we need and Batman is the hero we deserve i think that Captain Obvious i… https://t.co/T7ErIn0nKr
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @ebrahimian419 @PunkLVNFT Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# maxcao2204 tweeted:
# -----
# Check out this item on OpenSea https://t.co/r44NFn6eoi via @opensea
# #nft #NFTs #NFTCommunity #NFTartist… https://t.co/18PeRtCe3j
# -----
# # of likes: 1
# # of retweets: 0
# Tweet Value: 4.980485483103284
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# chair_house tweeted:
# -----
# Woo! 1 artwork sold! Thanks!! very happy!
#
# Finally I back to Eth #NFT artwork.
# I restart creating #NFT artworks ba… https://t.co/FE0CaE4sB6
# -----
# # of likes: 3
# # of retweets: 0
# Tweet Value: 4.941456449309852
# Account Value: 1.05
# Tweet Magnitude: 5.991456449309852
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# uddin633 tweeted:
# -----
# im looking for someone Who can donate me Ethereum:)
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# le_sh1n tweeted:
# -----
# @EthJackp Well if Superman is the hero that we need and Batman is the hero we deserve i think that Captain Obvious… https://t.co/Uvr7rF2o3T
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# AltcoinFGI tweeted:
# -----
# #Ethereum Fear and Greed Index is currently 39 - FEAR
#
# 24h technical analysis index: 39 - SELL
# Relative Strength In… https://t.co/lIJOLpYUkA
# -----
# # of likes: 1
# # of retweets: 1
# Tweet Value: 4.8903755929933945
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# BrightEbuka17 tweeted:
# -----
# @patelutkarsh143 @PunkLVNFT @PUNKLVUS Hi,are you in for exchange of nft for Bitcoin, smart chain BNB,ethereum,usdt
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# betty_eth_moon tweeted:
# -----
# @christa_platts @chukwuart @Mandalamintnft Check out this amazing project called #LuffyToken #LuffyV2 #NFT… https://t.co/AUPABLqbT3
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 6.05
# Sentiment: Positive
# -------------------------------------------------------------------------------
# Verified: False
# Ethnik_Gallery tweeted:
# -----
# @killerqueen_nft 👹DIRTY LITTLE DEVULS 👹
#
# ✨0.5 $ETH Ethereum 1/1 NFT✨
# ✨Drop on @opensea✨
# ✨https://t.co/NJYRcXqxQU ✨… https://t.co/DgexPppsp4
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: -3.95
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# WEFrensNFT tweeted:
# -----
# @IcedKnife You should be following us then!
#
# We are WE Frens, the cross-chain NFT project to unite NFT degens from… https://t.co/vEHxF3yLO2
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# Verified: False
# TheArtsRNotDead tweeted:
# -----
# Look what I found! German Shusky #2 collectible https://t.co/xiIiPZOGMi #rarible #ethereum #nonfungible #digitalasset #nft via @rarible
# -----
# # of likes: 2
# # of retweets: 0
# Tweet Value: 4.960970966206569
# Account Value: 1.05
# Tweet Magnitude: -3.910970966206569
# Sentiment: Negative
# -------------------------------------------------------------------------------
# Verified: False
# Vertumus_XDA tweeted:
# -----
# @flexpool_io @tjayrush @MicahZoltu @ethereum Does difficulty bomb is still coming in June or they are going to delay it?
# -----
# # of likes: 0
# # of retweets: 0
# Tweet Value: 5.0
# Account Value: 1.05
# Tweet Magnitude: 0
# Sentiment: Neutral
# -------------------------------------------------------------------------------
# CURRENT CONNOTATION: 256.7665944003643
